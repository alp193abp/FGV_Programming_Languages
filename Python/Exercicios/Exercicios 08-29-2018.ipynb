A EE Nelson Fernandes tem tradição nesse tipo de competição se vem destacando-se ao longo dos anos em eventos como Olimpíada Brasileira de Matemática das Escolas Públicas, Olimpíada Paulista de Matemática, Olimpíada Brasileira de Astronomia e Astronáutica (OBA), Mostra Brasileira de Foguetes (MOBFOG) e Jornada de Foguetes, Olimpíada Internacional de Astronomia e Astrofísica (OIAA), entre outros.

'''

# %%
texto
# Out:
# 'Os alunos da Escola Estadual Nelson Fernandes frequentemente são premiados em competições estudantis pelo Brasil, divulgando o nome de Santa Rita do Passa Quatro por onde passam e se destacam. Por este motivo, a escola tem sempre contado com o apoio do Governo Municipal, que dentro das possibilidades, ajuda no que é necessário. \n\nEsta semana, por intermédio do Prefeito Leandro Luciano dos Santos, os estudantes conseguiram um importante apoio. Atendendo ao pedido do Chefe do Executivo, a Comasa (Companhia Águas de Santa Rita), concessionária do serviço de saneamento básico do município, será a principal patrocinadora do grupo em mais um evento. \n\nCom o patrocínio e apoio de mais empresas do município, dessa vez os alunos da EE Nelson Fernandes irão participar do 5o Space Camp, um evento científico internacional, que acontece de 25 a 30 de julho, em Foz do Iguaçu (PR). Os alunos que representarão a escola e a cidade são: André Luis Juliate de Jesus e Atílio Leitão Pellegrino, que 
# ...

# %%
texto2=texto.split()
texto2
# Out:
# ['Os',
#  'alunos',
#  'da',
#  'Escola',
#  'Estadual',
#  'Nelson',
#  'Fernandes',
#  'frequentemente',
#  'são',
#  'premiados',
#  'em',
#  'competições',
#  'estudantis',
#  'pelo',
#  'Brasil,',
#  'divulgando',
#  'o',
#  'nome',
#  'de',
#  'Santa',
#  'Rita',
#  'do',
#  'Passa',
#  'Quatro',
#  'por',
#  'onde',
#  'passam',
#  'e',
#  'se',
#  'destacam.',
#  'Por',
#  'este',
#  'motivo,',
#  'a',
#  'escola',
#  'tem',
#  'sempre',
#  'contado',
#  'com',
#  'o',
#  'apoio',
#  'do',
#  'Governo',
#  'Municipal,',
#  'que',
#  'dentro',
#  'das',
#  'possibilidades,',
#  'ajuda',
#  'no',
#  'que',
#  'é',
#  'necessário.',
#  'Esta',
#  'semana,',
#  'por',
#  'intermédio',
#  'do',
#  'Prefeito',
#  'Leandro',
#  'Luciano',
#  'dos',
#  'Santos,',
#  'os',
#  'estudantes',
#  'conseguiram',
#  'um',
#  'importante',
#  'apoio.',
#  'Atendendo',
#  'ao',
#  'pedido',
#  'do',
#  'Chefe',
#  'do',
#  'Executivo,',
#  'a',
#  'Comasa',
#  '(Companhia',
#  'Águas',
# ...

# %%
texto3=[x.strip(string.punctuation+string.digits+'“'+'”'+'‘'+'’') for x in texto.split()]
texto3
# Out:
# ['Os',
#  'alunos',
#  'da',
#  'Escola',
#  'Estadual',
#  'Nelson',
#  'Fernandes',
#  'frequentemente',
#  'são',
#  'premiados',
#  'em',
#  'competições',
#  'estudantis',
#  'pelo',
#  'Brasil',
#  'divulgando',
#  'o',
#  'nome',
#  'de',
#  'Santa',
#  'Rita',
#  'do',
#  'Passa',
#  'Quatro',
#  'por',
#  'onde',
#  'passam',
#  'e',
#  'se',
#  'destacam',
#  'Por',
#  'este',
#  'motivo',
#  'a',
#  'escola',
#  'tem',
#  'sempre',
#  'contado',
#  'com',
#  'o',
#  'apoio',
#  'do',
#  'Governo',
#  'Municipal',
#  'que',
#  'dentro',
#  'das',
#  'possibilidades',
#  'ajuda',
#  'no',
#  'que',
#  'é',
#  'necessário',
#  'Esta',
#  'semana',
#  'por',
#  'intermédio',
#  'do',
#  'Prefeito',
#  'Leandro',
#  'Luciano',
#  'dos',
#  'Santos',
#  'os',
#  'estudantes',
#  'conseguiram',
#  'um',
#  'importante',
#  'apoio',
#  'Atendendo',
#  'ao',
#  'pedido',
#  'do',
#  'Chefe',
#  'do',
#  'Executivo',
#  'a',
#  'Comasa',
#  'Companhia',
#  'Águas',
#  'de',
# ...

# %%
dic1={palavra:texto3.count(palavra) for palavra in texto3}
dic1
# Out:
# {'': 3,
#  'A': 3,
#  'Acreditamos': 1,
#  'Acrux': 1,
#  'Aerospace': 1,
#  'Agropecuária': 1,
#  'Alessandro': 1,
#  'Além': 2,
#  'André': 1,
#  'Antonio': 2,
#  'Astrofísica': 1,
#  'Astronomia': 3,
#  'Astronáutica': 2,
#  'Atendendo': 1,
#  'Atílio': 1,
#  'Auto': 1,
#  'Automecânica': 1,
#  'Açaí': 1,
#  'Barão': 1,
#  'Borotto': 1,
#  'Brasil': 1,
#  'Brasileira': 4,
#  'Buffet': 1,
#  'CPP': 1,
#  'Camp': 3,
#  'Casa': 1,
#  'Center': 1,
#  'Centro': 1,
#  'Chefe': 1,
#  'Colina': 1,
#  'Com': 2,
#  'Comasa': 7,
#  'Companhia': 1,
#  'Consulti': 1,
#  'Contabilidade': 1,
#  'Deus': 1,
#  'Donizetti': 1,
#  'Drogaria': 1,
#  'E': 1,
#  'E.G': 1,
#  'EE': 2,
#  'Edutran': 1,
#  'Elétricos': 1,
#  'Em': 1,
#  'Embalagens': 1,
#  'Escola': 2,
#  'Escolas': 1,
#  'Escritório': 1,
#  'Esta': 1,
#  'Estadual': 1,
#  'Estamos': 1,
#  'Executivo': 1,
#  'Felix': 2,
#  'Fernandes': 3,
#  'Foguetes': 2,
#  'Foz': 1,
#  'Frios': 1,
#  'Funilaria': 1,
#  'Gerente': 1,
#  'Gima': 1,
# ...

# %%
dic1.pop('')
dic1
# Out:
# {'A': 3,
#  'Acreditamos': 1,
#  'Acrux': 1,
#  'Aerospace': 1,
#  'Agropecuária': 1,
#  'Alessandro': 1,
#  'Além': 2,
#  'André': 1,
#  'Antonio': 2,
#  'Astrofísica': 1,
#  'Astronomia': 3,
#  'Astronáutica': 2,
#  'Atendendo': 1,
#  'Atílio': 1,
#  'Auto': 1,
#  'Automecânica': 1,
#  'Açaí': 1,
#  'Barão': 1,
#  'Borotto': 1,
#  'Brasil': 1,
#  'Brasileira': 4,
#  'Buffet': 1,
#  'CPP': 1,
#  'Camp': 3,
#  'Casa': 1,
#  'Center': 1,
#  'Centro': 1,
#  'Chefe': 1,
#  'Colina': 1,
#  'Com': 2,
#  'Comasa': 7,
#  'Companhia': 1,
#  'Consulti': 1,
#  'Contabilidade': 1,
#  'Deus': 1,
#  'Donizetti': 1,
#  'Drogaria': 1,
#  'E': 1,
#  'E.G': 1,
#  'EE': 2,
#  'Edutran': 1,
#  'Elétricos': 1,
#  'Em': 1,
#  'Embalagens': 1,
#  'Escola': 2,
#  'Escolas': 1,
#  'Escritório': 1,
#  'Esta': 1,
#  'Estadual': 1,
#  'Estamos': 1,
#  'Executivo': 1,
#  'Felix': 2,
#  'Fernandes': 3,
#  'Foguetes': 2,
#  'Foz': 1,
#  'Frios': 1,
#  'Funilaria': 1,
#  'Gerente': 1,
#  'Gima': 1,
# ...

# %%
'joao'.endswith
# Out:
# <function str.endswith>

# %%
textodividido=texto.split()
l=[]
for x in range(2,len(textodividido)):
    y=textodividido[x]
    y.strip(string.punctuation)
    if not(textodividido[x-1].endswith('.')) and y.istitle():
        l.append(y.strip(string.punctuation))
print(l)
# Out:
# ['Escola', 'Estadual', 'Nelson', 'Fernandes', 'Brasil', 'Santa', 'Rita', 'Passa', 'Quatro', 'Governo', 'Municipal', 'Prefeito', 'Leandro', 'Luciano', 'Santos', 'Chefe', 'Executivo', 'Comasa', 'Companhia', 'Águas', 'Santa', 'Rita', 'Nelson', 'Fernandes', 'Space', 'Camp', 'Foz', 'Iguaçu', 'André', 'Luis', 'Juliate', 'Jesus', 'Atílio', 'Leitão', 'Pellegrino', 'Antonio', 'Otavio', 'Pellegrino', 'Tuca', 'Olimpíada', 'Brasileira', 'Astronomia', 'Astronáutica', 'Acrux', 'Aerospace', 'Technologies', 'Space', 'Camp', 'Itaipu', 'Space', 'Camp', 'Marte', 'Comasa', 'Gerente', 'Operações', 'Comasa', 'Felix', 'Antonio', 'Moura', 'Maria', 'Rita', 'Mondin', 'Oliveira', 'Vereador', 'Kleber', 'Alessandro', 'Borotto', 'Comasa', 'Comasa', 'Felix', 'Santa', 'Rita', 'Passa', 'Quatro”', 'Comasa', 'Santa', 'Rita', 'Comasa', 'O', 'Açaí', 'Santa', 'Hora', 'Buffet', 'Auto', 'Escola', 'Edutran', 'Drogaria', 'Total', 'Pousada', 'Colina', 'Laboratório', 'Santa', 'Rita', 'Center', 'Pack', 'Embalagens', 'Menon', 'F
# ...

# %%
import string
c=0
texto = 'Seu protagonista é Bento Santiago, o narrador da história que, contada em primeira pessoa, pretende "atar as duas pontas da vida", ou seja, unir relatos desde sua mocidade até os dias em que está escrevendo o livro. Entre esses dois momentos, Bento escreve sobre suas reminiscências da juventude, sua vida no seminário, seu caso com Capitu e o ciúme que advém desse relacionamento, que se torna o enredo central da trama. Ambientado no Rio de Janeiro do Segundo Império, se inicia com um episódio que seria recente, no qual o narrador recebe a alcunha de "Dom Casmurro", daí o título do romance. Machado de Assis o escreveu utilizando ferramentas literárias como a ironia e a intertextualidade, fazendo referências a Schopenhauer e, sobretudo, à peça Otelo, o Mouro de Veneza de Shakespeare.'
textodiv=texto.split()
maior=textodiv.index(textodiv[-1])
listapalavras={}
quantidadepalavraspropriasunicas=0
palavraspropriasunicas=[]
for y in range(0,(maior+1)):
    x=textodiv[y]
    x=x.strip(string.punctuation)
    if (x.lower()) in listapalavras:
        x=x.lower()
        for key in listapalavras.keys():
            if x == key:
                listapalavras[key]=listapalavras[key]+1
    else:
        if c==1:
            if x.istitle() and not(textodiv[y-1].endswith('.')):
                palavraspropriasunicas.append(x)
                quantidadepalavraspropriasunicas=quantidadepalavraspropriasunicas+1
        x=x.lower()
        listapalavras[x]=1
    c=1
